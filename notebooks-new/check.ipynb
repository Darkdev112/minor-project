# %%
import xarray as xr

# %%
data = xr.open_dataset('../data/aqi2/MERRA2_300.tavgM_2d_chm_Nx.200501.nc4')
data
# Out:
# <xarray.Dataset> Size: 12MB
# Dimensions:   (lon: 576, lat: 361, time: 1)
# Coordinates:
#   * lon       (lon) float64 5kB -180.0 -179.4 -178.8 ... 178.1 178.8 179.4
#   * lat       (lat) float64 3kB -90.0 -89.5 -89.0 -88.5 ... 88.5 89.0 89.5 90.0
#   * time      (time) datetime64[ns] 8B 2005-01-01T00:30:00
# Data variables: (12/14)
#     COCL      (time, lat, lon) float32 832kB ...
#     COEM      (time, lat, lon) float32 832kB ...
#     COLS      (time, lat, lon) float32 832kB ...
#     COPD      (time, lat, lon) float32 832kB ...
#     COSC      (time, lat, lon) float32 832kB ...
#     LWI       (time, lat, lon) float32 832kB ...
#     ...        ...
#     Var_COEM  (time, lat, lon) float32 832kB ...
#     Var_COLS  (time, lat, lon) float32 832kB ...
#     Var_COPD  (time, lat, lon) float32 832kB ...
#     Var_COSC  (time, lat, lon) float32 832kB ...
#     Var_LWI   (time, lat, lon) float32 832kB ...
#     Var_TO3   (time, lat, lon) float32 832kB ...
# Attributes: (12/30)
# ...

# %%
print(data['COSC'][0].attrs)
print(data['COSC'][0].values[0][0])
# Out:
# {'long_name': 'CO Surface Concentration in ppbv __ENSEMBLE__', 'units': '1e-9', 'fmissing_value': 1000000000000000.0, 'vmax': 1000000000000000.0, 'vmin': -1000000000000000.0, 'valid_range': array([-1.e+15,  1.e+15], dtype=float32)}
# 36.174133

# %%
# 1 DU = 21.415 µg(O3)/m3
